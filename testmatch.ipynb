# %% [markdown]
# # TEST CRICKET MATCH DATASET

# %% [markdown]
# ## Introduction

# %% [markdown]
# * Test cricket is a form of first-class cricket played at international level between teams representing full member countries of the International Cricket Council (ICC). A match consists of four innings (two per team) and is scheduled to last for up to five days. In the past, some Test matches had no time limit and were called Timeless Tests. The term "test match" was originally coined in 1861–62 but in a different context.

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# * we have sample data listing  Player name,	Span,Match,	Innings, Not out,Runs,High score,Average score depending on any column or not and if depending which columns are more responsible for that.

# %% [markdown]
# ## Source of The Dataset

# %% [markdown]
# * We collected this dataset from kaggle
# * https://www.kaggle.com/datasets/mahendran1/icc-cricket/data

# %% [markdown]
# ## Size of the Dataset

# %% [markdown]
# * The size of the dataset is 168KB

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Player', 'Span', 'Mat', 'Inns', 'NO', 'Runs', 'HS',
#        'Ave', '100', '50', '0', 'Unnamed: 11'],
#       dtype='object')

# %% [markdown]
# ## About the Dataset

# %% [markdown]
# * Test dataset contains a sample of data giving an overview of the players along with the countries they represented, playing span, number of matches ,innings and not out the played,their high and average score and number of century and half century they scored.
# * This dataset contains 13 columns namely -'Unnamed: 0', 'Player', 'Span', 'Mat', 'Inns', 'NO', 'Runs', 'HS',
#        'Ave', '100', '50', '0', 'Unnamed: 11'

# %% [markdown]
# ## Libraries Used
# * Numpy
# * Pandas
# * Matplotlib
# * Seaborn

# %% [markdown]
# ## Importing Required Libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Loading The Dataset

# %%
df=pd.read_csv('test.csv')
df
# Out:
#       Unnamed: 0                Player       Span  Mat Inns  NO   Runs    HS  \
# 0              0  SR Tendulkar (INDIA)  1989-2013  200  329  33  15921  248*
# 1              1      RT Ponting (AUS)  1995-2012  168  287  29  13378   257
# 2              2    JH Kallis (ICC/SA)  1995-2013  166  280  40  13289   224
# 3              3  R Dravid (ICC/INDIA)  1996-2012  164  286  32  13288   270
# 4              4         AN Cook (ENG)  2006-2018  161  291  16  12472   294
# ...          ...                   ...        ...  ...  ...  ..    ...   ...
# 2996          46       CA Snedden (NZ)  1947-1947    1    -   -      -     -
# 2997          47      VN Swamy (INDIA)  1955-1955    1    -   -      -     -
# 2998          48  Usman Shinwari (PAK)  2019-2019    1    -   -      -     -
# 2999          49    CM Willoughby (SA)  2003-2003    2    -   -      -     -
# 3000           0       JW Wilson (AUS)  1956-1956    1    -   -      -     -
#
#         Ave 100  50   0  Unnamed: 11
# ...

# %% [markdown]
# ## Missing Values

# %%
(df.isnull().sum()/len(df))*100
# Out:
# Unnamed: 0       0.000000
# Player           0.000000
# Span             0.000000
# Mat              0.000000
# Inns             0.000000
# NO               0.000000
# Runs             0.033322
# HS               0.000000
# Ave              0.000000
# 100              0.000000
# 50               0.033322
# 0                0.033322
# Unnamed: 11    100.000000
# dtype: float64

# %% [markdown]
# * There are so many missing value present in  column Unnamed:11 . so we have to drop this column. Also we do not required the column named Unnamed:0, So we will also drop this column as well.

# %%
df.drop('Unnamed: 0',axis=1,inplace=True)
df.drop('Unnamed: 11',axis=1,inplace=True)
df
# Out:
#                     Player       Span  Mat Inns  NO   Runs    HS    Ave 100  \
# 0     SR Tendulkar (INDIA)  1989-2013  200  329  33  15921  248*  53.78  51
# 1         RT Ponting (AUS)  1995-2012  168  287  29  13378   257  51.85  41
# 2       JH Kallis (ICC/SA)  1995-2013  166  280  40  13289   224  55.37  45
# 3     R Dravid (ICC/INDIA)  1996-2012  164  286  32  13288   270  52.31  36
# 4            AN Cook (ENG)  2006-2018  161  291  16  12472   294  45.35  33
# ...                    ...        ...  ...  ...  ..    ...   ...    ...  ..
# 2996       CA Snedden (NZ)  1947-1947    1    -   -      -     -      -   -
# 2997      VN Swamy (INDIA)  1955-1955    1    -   -      -     -      -   -
# 2998  Usman Shinwari (PAK)  2019-2019    1    -   -      -     -      -   -
# 2999    CM Willoughby (SA)  2003-2003    2    -   -      -     -      -   -
# 3000       JW Wilson (AUS)  1956-1956    1    -   -      -     -      -   -
#
#       50   0
# 0     68  14
# 1     62  17
# ...

# %%
df.rename(columns={'100':'Centuries','50':'Half centuries','0':'Zeros'},inplace=True)
df
# Out:
#                     Player       Span  Mat Inns  NO   Runs    HS    Ave  \
# 0     SR Tendulkar (INDIA)  1989-2013  200  329  33  15921  248*  53.78
# 1         RT Ponting (AUS)  1995-2012  168  287  29  13378   257  51.85
# 2       JH Kallis (ICC/SA)  1995-2013  166  280  40  13289   224  55.37
# 3     R Dravid (ICC/INDIA)  1996-2012  164  286  32  13288   270  52.31
# 4            AN Cook (ENG)  2006-2018  161  291  16  12472   294  45.35
# ...                    ...        ...  ...  ...  ..    ...   ...    ...
# 2996       CA Snedden (NZ)  1947-1947    1    -   -      -     -      -
# 2997      VN Swamy (INDIA)  1955-1955    1    -   -      -     -      -
# 2998  Usman Shinwari (PAK)  2019-2019    1    -   -      -     -      -
# 2999    CM Willoughby (SA)  2003-2003    2    -   -      -     -      -
# 3000       JW Wilson (AUS)  1956-1956    1    -   -      -     -      -
#
#      Centuries Half centuries Zeros
# 0           51             68    14
# ...

# %% [markdown]
# ## Remove ( from column player and split into region column)

# %%
df[['Player', 'Region']] = df['Player'].str.split('(', n=1, expand=True)
df.head(5)
# Out:
#           Player       Span  Mat Inns  NO   Runs    HS    Ave Centuries  \
# 0  SR Tendulkar   1989-2013  200  329  33  15921  248*  53.78        51
# 1    RT Ponting   1995-2012  168  287  29  13378   257  51.85        41
# 2     JH Kallis   1995-2013  166  280  40  13289   224  55.37        45
# 3      R Dravid   1996-2012  164  286  32  13288   270  52.31        36
# 4       AN Cook   2006-2018  161  291  16  12472   294  45.35        33
#
#   Half centuries Zeros      Region
# 0             68    14      INDIA)
# 1             62    17        AUS)
# 2             58    16     ICC/SA)
# 3             63     8  ICC/INDIA)
# 4             57     9        ENG)

# %%
df['Region']=df['Region'].str.replace(')','')
df
# Out:
#                Player       Span  Mat Inns  NO   Runs    HS    Ave Centuries  \
# 0       SR Tendulkar   1989-2013  200  329  33  15921  248*  53.78        51
# 1         RT Ponting   1995-2012  168  287  29  13378   257  51.85        41
# 2          JH Kallis   1995-2013  166  280  40  13289   224  55.37        45
# 3           R Dravid   1996-2012  164  286  32  13288   270  52.31        36
# 4            AN Cook   2006-2018  161  291  16  12472   294  45.35        33
# ...               ...        ...  ...  ...  ..    ...   ...    ...       ...
# 2996      CA Snedden   1947-1947    1    -   -      -     -      -         -
# 2997        VN Swamy   1955-1955    1    -   -      -     -      -         -
# 2998  Usman Shinwari   2019-2019    1    -   -      -     -      -         -
# 2999   CM Willoughby   2003-2003    2    -   -      -     -      -         -
# 3000       JW Wilson   1956-1956    1    -   -      -     -      -         -
#
#      Half centuries Zeros     Region
# ...

# %% [markdown]
# ## Finding Null values

# %%
df[df['Runs'].isna()==1]
# Out:
#           Player       Span  Mat Inns NO Runs   HS    Ave Centuries  \
# 162  EH Hendren   1920-1935   51   83  9  NaN  205  47.63         7
#
#     Half centuries Zeros Region Start   End
# 162             21     4    ENG  1920  1935

# %%
df[df['Half centuries'].isna()==1]
# Out:
#          Player       Span  Mat Inns NO  Runs   HS    Ave Centuries  \
# 199  KR Miller   1946-1956   55   87  7  2958  147  36.97         7
#
#     Half centuries Zeros Region
# 199            NaN     5    AUS

# %%
df[df['Zeros'].isna()==1]
# Out:
#           Player       Span  Mat Inns  NO  Runs   HS    Ave Centuries  \
# 327  L Klusener   1996-2004   49   69  11  1906  174  32.86         4
#
#     Half centuries Zeros Region
# 327              8   NaN     SA

# %% [markdown]
# * We can see that null values are present in Runs,half centuries and Zeros column.

# %% [markdown]
# ## Filling null values with 0

# %%
df['Runs']=df['Runs'].fillna(0)
df['Half centuries']=df['Half centuries'].fillna(0)
df['Zeros']=df['Zeros'].fillna(0)
df
# Out:
#                Player       Span  Mat Inns  NO   Runs   HS    Ave Centuries  \
# 0       SR Tendulkar   1989-2013  200  329  33  15921  248  53.78        51
# 1         RT Ponting   1995-2012  168  287  29  13378  257  51.85        41
# 2          JH Kallis   1995-2013  166  280  40  13289  224  55.37        45
# 3           R Dravid   1996-2012  164  286  32  13288  270  52.31        36
# 4            AN Cook   2006-2018  161  291  16  12472  294  45.35        33
# ...               ...        ...  ...  ...  ..    ...  ...    ...       ...
# 2996      CA Snedden   1947-1947    1    0   0      0    0      0         0
# 2997        VN Swamy   1955-1955    1    0   0      0    0      0         0
# 2998  Usman Shinwari   2019-2019    1    0   0      0    0      0         0
# 2999   CM Willoughby   2003-2003    2    0   0      0    0      0         0
# 3000       JW Wilson   1956-1956    1    0   0      0    0      0         0
#
#      Half centuries Zeros     Region Start   End
# ...

# %% [markdown]
# * We fill the null values with 0

# %% [markdown]
# ## Spliting the Span column

# %%
df[['Start', 'End']] = df['Span'].str.split("-", n=1, expand=True)
df.head(5)
# Out:
#           Player       Span  Mat Inns  NO   Runs    HS    Ave Centuries  \
# 0  SR Tendulkar   1989-2013  200  329  33  15921  248*  53.78        51
# 1    RT Ponting   1995-2012  168  287  29  13378   257  51.85        41
# 2     JH Kallis   1995-2013  166  280  40  13289   224  55.37        45
# 3      R Dravid   1996-2012  164  286  32  13288   270  52.31        36
# 4       AN Cook   2006-2018  161  291  16  12472   294  45.35        33
#
#   Half centuries Zeros     Region Start   End
# 0             68    14      INDIA  1989  2013
# 1             62    17        AUS  1995  2012
# 2             58    16     ICC/SA  1995  2013
# 3             63     8  ICC/INDIA  1996  2012
# 4             57     9        ENG  2006  2018

# %% [markdown]
# * We split the Span column into Start and End.

# %%
df['Runs']=df['Runs'].str.replace('-','0')
df['HS']=df['HS'].str.replace('*','')
df['Ave']=df['Ave'].str.replace('-','0')
df['Inns']=df['Inns'].str.replace('-','0')
df['NO']=df['NO'].str.replace('-','0')
df['HS']=df['HS'].str.replace('-','0')
df['Centuries']=df['Centuries'].str.replace('-','0')
df['Half centuries']=df['Half centuries'].str.replace('-','0')
df['Zeros']=df['Zeros'].str.replace('-','0')
df
# Out:
#                Player       Span  Mat Inns  NO   Runs   HS    Ave Centuries  \
# 0       SR Tendulkar   1989-2013  200  329  33  15921  248  53.78        51
# 1         RT Ponting   1995-2012  168  287  29  13378  257  51.85        41
# 2          JH Kallis   1995-2013  166  280  40  13289  224  55.37        45
# 3           R Dravid   1996-2012  164  286  32  13288  270  52.31        36
# 4            AN Cook   2006-2018  161  291  16  12472  294  45.35        33
# ...               ...        ...  ...  ...  ..    ...  ...    ...       ...
# 2996      CA Snedden   1947-1947    1    0   0      0    0      0         0
# 2997        VN Swamy   1955-1955    1    0   0      0    0      0         0
# 2998  Usman Shinwari   2019-2019    1    0   0      0    0      0         0
# 2999   CM Willoughby   2003-2003    2    0   0      0    0      0         0
# 3000       JW Wilson   1956-1956    1    0   0      0    0      0         0
#
#      Half centuries Zeros     Region Start   End
# ...

# %% [markdown]
# ## Duplicate Values

# %%
df.duplicated().isnull().sum()
# Out:
# 0

# %% [markdown]
# * There are no duplicate values present in this dataset.

# %% [markdown]
# ## Data Description

# %% [markdown]
# * We have both categorical and non categorical columns in this dataset.
# * Categorical columns are Player,Region.
# * Non categorical columns are Span,Mat,Inns,NO,Runs, HS, Ave, Centuries,Half centuries, Zeros,Start, End
#       '

# %% [markdown]
# ## Data Processing

# %%
df.head(5)
# Out:
#           Player       Span  Mat Inns  NO   Runs    HS    Ave Centuries  \
# 0  SR Tendulkar   1989-2013  200  329  33  15921  248*  53.78        51
# 1    RT Ponting   1995-2012  168  287  29  13378   257  51.85        41
# 2     JH Kallis   1995-2013  166  280  40  13289   224  55.37        45
# 3      R Dravid   1996-2012  164  286  32  13288   270  52.31        36
# 4       AN Cook   2006-2018  161  291  16  12472   294  45.35        33
#
#   Half centuries Zeros     Region Start   End
# 0             68    14      INDIA  1989  2013
# 1             62    17        AUS  1995  2012
# 2             58    16     ICC/SA  1995  2013
# 3             63     8  ICC/INDIA  1996  2012
# 4             57     9        ENG  2006  2018

# %%
df.tail(5)
# Out:
#                Player       Span  Mat Inns NO Runs HS Ave Centuries  \
# 2996      CA Snedden   1947-1947    1    -  -    -  -   -         -
# 2997        VN Swamy   1955-1955    1    -  -    -  -   -         -
# 2998  Usman Shinwari   2019-2019    1    -  -    -  -   -         -
# 2999   CM Willoughby   2003-2003    2    -  -    -  -   -         -
# 3000       JW Wilson   1956-1956    1    -  -    -  -   -         -
#
#      Half centuries Zeros Region Start   End
# 2996              -     -     NZ  1947  1947
# 2997              -     -  INDIA  1955  1955
# 2998              -     -    PAK  2019  2019
# 2999              -     -     SA  2003  2003
# 3000              -     -    AUS  1956  1956

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3001 entries, 0 to 3000
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Player          3001 non-null   object
#  1   Span            3001 non-null   object
#  2   Mat             3001 non-null   int64
#  3   Inns            3001 non-null   object
#  4   NO              3001 non-null   object
#  5   Runs            3001 non-null   object
#  6   HS              3001 non-null   object
#  7   Ave             3001 non-null   object
#  8   Centuries       3001 non-null   object
#  9   Half centuries  3001 non-null   object
#  10  Zeros           3001 non-null   object
#  11  Region          3001 non-null   object
#  12  Start           3001 non-null   object
#  13  End             3001 non-null   object
# dtypes: int64(1), object(13)
# memory usage: 328.4+ KB

# %%
df.describe()
# Out:
#                Mat
# count  3001.000000
# mean     17.427191
# std      24.954654
# min       1.000000
# 25%       2.000000
# 50%       7.000000
# 75%      21.000000
# max     200.000000

# %%
df.shape
# Out:
# (3001, 14)

# %%
df.sample(3)
# Out:
#               Player       Span  Mat Inns NO  Runs   HS    Ave Centuries  \
# 233   Mominul Haque   2013-2019   38   71  4  2657  181  39.65         8
# 2275     AW Briscoe   1935-1939    2    3  0    33   16     11         0
# 1957       CV Wight   1928-1930    2    4  1    67   23  22.33         0
#
#      Half centuries Zeros Region Start   End
# 233              13     8  BDESH  2013  2019
# 2275              0     0     SA  1935  1939
# 1957              0     0     WI  1928  1930

# %% [markdown]
# ## Various features in Test Cricket dataset

# %%
df.columns
# Out:
# Index(['Player', 'Span', 'Mat', 'Inns', 'NO', 'Runs', 'HS', 'Ave', 'Centuries',
#        'Half centuries', 'Zeros', 'Region', 'Start', 'End'],
#       dtype='object')

# %% [markdown]
# # Types of each feature in dataset

# %%
df.dtypes
# Out:
# Player            object
# Span              object
# Mat                int64
# Inns              object
# NO                object
# Runs              object
# HS                object
# Ave               object
# Centuries         object
# Half centuries    object
# Zeros             object
# Region            object
# Start             object
# End               object
# dtype: object

# %% [markdown]
# ## Changing the data types

# %%
df=df.astype({'Inns':'int','NO':'int','Runs':'int','HS':'int','Ave':'float','Centuries':'int','Half centuries':'int','Zeros':'int','Start':'int','End':'int'})

# %%
df.dtypes
# Out:
# Player             object
# Span               object
# Mat                 int64
# Inns                int32
# NO                  int32
# Runs                int32
# HS                  int32
# Ave               float64
# Centuries           int32
# Half centuries      int32
# Zeros               int32
# Region             object
# Start               int32
# End                 int32
# dtype: object

# %%
df[['Play ICC','Do not play ICC']] = df['Region'].str.split("/", n=1, expand=True)
df
# Out:
#                Player       Span  Mat  Inns  NO   Runs   HS    Ave  Centuries  \
# 0       SR Tendulkar   1989-2013  200   329  33  15921  248  53.78         51
# 1         RT Ponting   1995-2012  168   287  29  13378  257  51.85         41
# 2          JH Kallis   1995-2013  166   280  40  13289  224  55.37         45
# 3           R Dravid   1996-2012  164   286  32  13288  270  52.31         36
# 4            AN Cook   2006-2018  161   291  16  12472  294  45.35         33
# ...               ...        ...  ...   ...  ..    ...  ...    ...        ...
# 2996      CA Snedden   1947-1947    1     0   0      0    0   0.00          0
# 2997        VN Swamy   1955-1955    1     0   0      0    0   0.00          0
# 2998  Usman Shinwari   2019-2019    1     0   0      0    0   0.00          0
# 2999   CM Willoughby   2003-2003    2     0   0      0    0   0.00          0
# 3000       JW Wilson   1956-1956    1     0   0      0    0   0.00          0
#
# ...

# %%
_=df.groupby('Player')['Centuries'].max().sort_values(ascending=False).head(10).plot.pie(title='Player with maximum number of centuries',autopct='%1.2f%%')

# %%
x=df.groupby('Player')['Centuries'].max().sort_values(ascending=False).head(10)
x
# Out:
# Player
# SR Tendulkar         51
# JH Kallis            45
# RT Ponting           41
# KC Sangakkara        38
# R Dravid             36
# Younis Khan          34
# SM Gavaskar          34
# BC Lara              34
# DPMD Jayawardene     34
# AN Cook              33
# Name: Centuries, dtype: int32

# %%
df['Do not play ICC']=df['Do not play ICC'].str.replace('ICC','Do not played under ICC')
df['Do not play ICC'].unique()
# Out:
# array([None, 'SA', 'INDIA', 'WI', 'PAK', 'NZ', 'Do not played under ICC',
#        'SL', 'ENG', 'IRE', 'ZIM'], dtype=object)

# %% [markdown]
# ## Checking number of unique values of each column

# %%
df['Do not play ICC'].unique()
# Out:
# array([None, 'SA', 'INDIA', 'WI', 'PAK', 'NZ', 'Do not played under ICC',
#        'SL', 'ENG', 'IRE', 'ZIM'], dtype=object)

# %%
df.nunique()
# Out:
# Player             2986
# Span               1140
# Mat                 134
# Inns                198
# NO                   48
# Runs               1186
# HS                  293
# Ave                1597
# Centuries            39
# Half centuries       56
# Zeros                34
# Region               28
# Start               128
# End                 124
# Play ICC             14
# Do not play ICC      10
# dtype: int64

# %%
df['Player'].unique()
# Out:
# array(['SR Tendulkar ', 'RT Ponting ', 'JH Kallis ', ...,
#        'Usman Shinwari ', 'CM Willoughby ', 'JW Wilson '], dtype=object)

# %%
df['Span'].unique()
# Out:
# array(['1989-2013', '1995-2012', '1995-2013', ..., '1902-1907',
#        '1893-1893', '1926-1926'], dtype=object)

# %%
df['Mat'].unique()
# Out:
# array([200, 168, 166, 164, 161, 134, 131, 149, 156, 125, 118, 124, 117,
#        120, 114, 115, 103, 104, 121, 133, 108,  93, 128, 105,  90, 110,
#        116, 107,  89, 101,  85, 113,  84, 111,  72,  98,  87,  83, 100,
#         52,  79,  82,  78,  99,  91,  86,  77,  76,  96, 102,  75, 147,
#         81,  61,  74,  67,  62,  63,  66,  54,  70,  73,  48,  64,  95,
#         69, 119,  59,  58,  71,  68,  56,  55,  51,  80,  88,  44,  60,
#         57,  50,  49,  46,  42,  65, 135, 145,  47,  43,  41,  34,  39,
#         40,  38,  45,  53,  37,  29,  30, 132,  35,  23,  22,  32,  36,
#         27,  25,  28,  26,  31,  33,  21,  24,  20,  19,  15,  18,  92,
#         13,  17, 150,  16,  12,  14,  10,  11,   9,   8,   7,   4,   6,
#          5,   2,   3,   1], dtype=int64)

# %%
df['Inns'].unique()
# Out:
# array([329, 287, 280, 286, 291, 233, 232, 252, 265, 260, 214, 213, 215,
#        205, 189, 200, 225, 191, 198, 184, 180, 182, 235, 204, 181, 193,
#        160, 209, 212, 188, 185, 156, 186, 175, 202, 190, 164, 176, 140,
#        141, 130, 173, 151, 153, 178,  80, 138, 131, 179, 137, 159, 147,
#        154, 155, 146, 143, 171, 124, 206, 145, 132, 102, 125, 136, 148,
#        123, 161, 127, 144, 111, 112, 120, 139,  84, 115, 106, 174, 122,
#         81, 109, 149, 113, 129,  99, 104, 116, 105,  91,  97,  87, 100,
#         93, 121, 126,  74, 110, 150,  89,  94,  88,  86,  79,  83,  98,
#        114, 108,  92,  96,  78, 199, 134, 162,  69,  90,  73,  62,  76,
#         77, 128,  71,  82,  65,  70, 119,  68,  85,  66,  54,  57,  63,
#         64, 133,  72,  58,  41,  52,  40,  56,  53,  55,  48,  46,  49,
#         61,  60, 107,  50,  42,  59,  47,  39,  45,  44,  38,  35,  43,
#         31,  36,  37,  33,  67,  32,  34,  29,  51,  21,  26, 211,  27,
# ...

# %% [markdown]
# ## Top 10 players who played maximum number of matches

# %%
c=['#D0A2F7','#FA7070','#D2DE32','#CE5A67','#557C55','#AF2655','#016A70','#D2DE32','#241468','#EA1179']
_=df.groupby('Player')['Mat'].max().sort_values(ascending=False).head(10).plot.bar(color=c)

# %% [markdown]
# * Sachin Tendulkar played most number of matches.

# %% [markdown]
# ## 10 players who played minimum number of matches

# %%
c=['red','yellow','black','blue','cyan','orange','purple','pink','maroon','navy','teal']
_=df.groupby('Player')['Mat'].max().sort_values(ascending=True).head(10).plot.bar(color=c)

# %%
plt.figure(figsize=(10,8))
_=sns.distplot(df['Ave'])
# Out:
# C:\Users\RESHMI\AppData\Local\Temp\ipykernel_6560\713610941.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   _=sns.distplot(df['Ave'])

# %% [markdown]
# ## Top 10 players who have maximum average score

# %%
c=['#C51605','#FD8D14','#CECE5A','#FFE17B','#F31559','#068FFF','#FF2171','#FF90BB','#3AA6B9','#F2BE22']
_=df.groupby('Player')['Ave'].max().sort_values(ascending=False).head(10).plot.bar(color=c)

# %%
df['Region'].value_counts().head(5)
# Out:
# Region
# ENG      684
# AUS      452
# SA       335
# WI       318
# INDIA    290
# Name: count, dtype: int64

# %%
plt.figure(figsize=(6,6))
_=sns.countplot(y='Region',data=df)
plt.show()

# %% [markdown]
# * Most of the players are from England.

# %%
df['Runs'].head(15).plot.box(color='red')
# Out:
# <Axes: >

# %%
df['Half centuries'].head(20).plot.box()
# Out:
# <Axes: >

# %%
z=df[(df['Region']=='INDIA')&(df['Start']==1989)]
z
# Out:
#                 Player       Span  Mat  Inns  NO   Runs   HS    Ave  \
# 0        SR Tendulkar   1989-2013  200   329  33  15921  248  53.78
# 2754        SA Ankola   1989-1989    1     1   0      6    6   6.00
# 2783         V Razdan   1989-1989    2     2   1      6    6   6.00
# 2976  M Venkataramana   1989-1989    1     2   2      0    0   0.00
#
#       Centuries  Half centuries  Zeros Region  Start   End
# 0            51              68     14  INDIA   1989  2013
# 2754          0               0      0  INDIA   1989  1989
# 2783          0               0      1  INDIA   1989  1989
# 2976          0               0      0  INDIA   1989  1989

# %%
df['Runs'].plot.hist(range=[1000,2000],color='#FF2171')
# Out:
# <Axes: ylabel='Frequency'>

# %%
_=df['Runs'].plot.hist()

# %%
_=df.groupby('Player')['Mat'].max().sort_values(ascending=True).head(5).plot.pie(title='Players',autopct='%1.2f%%')

# %%
a=df.groupby('Player')['Centuries'].max().sort_values(ascending=False).head(5)
a
# Out:
# Player
# SR Tendulkar      51
# JH Kallis         45
# RT Ponting        41
# KC Sangakkara     38
# R Dravid          36
# Name: Centuries, dtype: int32

# %%
df.groupby('Ave')['Player'].max().sort_values(ascending=False).head(10)
# Out:
# Ave
# 44.00    Zulqarnain Haider
# 6.00            Zulqarnain
# 16.00       Zulfiqar Babar
# 33.33       Zulfiqar Ahmed
# 24.33         Zubayr Hamza
# 7.00          Ziaur Rahman
# 0.00            Zakir Khan
# 10.00         Zahoor Elahi
# 18.00          Zahid Fazal
# 44.79         Zaheer Abbas
# Name: Player, dtype: object

# %%
_=plt.figure(figsize=(12,20))
sns.displot(x='Ave',data=df)
plt.show()
# Out:
# C:\Users\RESHMI\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
df['Do not play ICC'].value_counts()
# Out:
# Do not play ICC
# SA       6
# ENG      5
# PAK      4
# INDIA    3
# WI       2
# ICC      2
# NZ       1
# SL       1
# IRE      1
# ZIM      1
# Name: count, dtype: int64

# %%
df['Do not play ICC'].value_counts().plot.pie(autopct='%1.0f%%')
# Out:
# <Axes: ylabel='count'>

# %%
df.groupby('Ave')['Do not play ICC'].value_counts()
# Out:
# Ave    Do not play ICC
# 3.16   ZIM                1
# 8.60   IRE                1
# 8.76   ENG                1
# 10.25  PAK                1
# 11.60  SA                 1
# 11.67  SL                 1
# 11.79  0                  1
# 12.81  PAK                1
# 13.45  ENG                1
# 15.40  ENG                1
# 16.80  SA                 1
# 19.90  INDIA              1
# 20.20  WI                 1
# 23.76  PAK                1
# 30.00  NZ                 1
# 30.30  SA                 1
# 31.31  ENG                1
# 31.77  0                  1
# 38.00  ENG                1
# 41.00  SA                 1
# 48.25  SA                 1
# 49.34  INDIA              1
# 49.60  PAK                1
# 52.31  INDIA              1
# 52.88  WI                 1
# 55.37  SA                 1
# Name: count, dtype: int64

# %%
_=sns.boxplot(x='Ave',y='Do not play ICC',data=df.sort_values(by='Do not play ICC',ascending=False))

# %%
sns.violinplot(x='Do not play ICC',y='Ave',data=df,palette=['#13D95E','#1331D9','#CA13D9','#17DAD4'])
# Out:
# <Axes: xlabel='Do not play ICC', ylabel='Ave'>

# %%
plt.pie(Avg[:5],autopct='%1.2F%%')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[78], line 1
# ----> 1 plt.pie(Avg[:5],autopct='%1.2F%%')
#       2 plt.show()
#
# NameError: name 'Avg' is not defined
